# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("Crimes_-_2001_to_present.csv")

# %%
print(df[df['Year'] == 2005].Block.value_counts())
# Out:
# 100XX W OHARE ST                       1271
# 023XX S STATE ST                        916
# 076XX S CICERO AVE                      732
# 001XX N STATE ST                        612
# 022XX S STATE ST                        575
# 063XX S DR MARTIN LUTHER KING JR DR     571
# 012XX N BURLING ST                      563
# 005XX E BROWNING AVE                    551
# 062XX S CALUMET AVE                     501
# 015XX W 13TH ST                         500
# 0000X N STATE ST                        495
# 029XX S STATE ST                        472
# 001XX W 87TH ST                         446
# 027XX S DEARBORN ST                     443
# 008XX N MICHIGAN AVE                    425
# 024XX W MONROE ST                       395
# 024XX S STATE ST                        375
# 006XX W DIVISION ST                     369
# 064XX S DR MARTIN LUTHER KING JR DR     364
# 027XX W OGDEN AVE                       341
# 012XX S WABASH AVE                      332
# ...

# %%
print(df.columns.values)
# Out:
# ['ID' 'Case Number' 'Date' 'Block' 'IUCR' 'Primary Type' 'Description'
#  'Location Description' 'Arrest' 'Domestic' 'Beat' 'District' 'Ward'
#  'Community Area' 'FBI Code' 'X Coordinate' 'Y Coordinate' 'Year'
#  'Updated On' 'Latitude' 'Longitude' 'Location']

# %%
small_df = df[df['Year'] == 2001]
small_df = small_df[small_df['Block'] == '100XX W OHARE ST']
small_df['Primary Type'].value_counts()
# Out:
# THEFT                         746
# DECEPTIVE PRACTICE            254
# CRIMINAL TRESPASS             198
# CRIMINAL DAMAGE               154
# MOTOR VEHICLE THEFT           135
# BATTERY                       134
# ASSAULT                        63
# WEAPONS VIOLATION              45
# NARCOTICS                      44
# OTHER OFFENSE                  44
# PUBLIC PEACE VIOLATION         18
# BURGLARY                       15
# SEX OFFENSE                     7
# LIQUOR LAW VIOLATION            3
# ROBBERY                         2
# OFFENSE INVOLVING CHILDREN      2
# PROSTITUTION                    1
# INTIMIDATION                    1
# Name: Primary Type, dtype: int64

# %%
years = (2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017)
Ohare = {}
for year in years:
    small_df = df[df['Year'] == year]
    small_df = small_df[small_df['Block'] == '100XX W OHARE ST']
    Ohare[year] = small_df['Primary Type'].value_counts()

# %%
print(type(Ohare[2001]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
Ohare_Theft = []
for year in years:
    Ohare_Theft.append(Ohare[year]['THEFT'])

fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,Ohare_Theft)
plt.title("Theft Rate - O'Hare ST 2001-2017")
plt.xlabel('Theft')
plt.ylabel('Year')
plt.show()
plt.savefig('theftohare.png')

# %%
plot_list = []
for year in years:
    try:
        plot_list.append(Ohare[year]['BATTERY'])
    except:
        plot_list.append(0)

fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,plot_list)
plt.title("Battery Rate - O'Hare ST 2001-2017")
plt.xlabel('Battery')
plt.ylabel('Year')
plt.savefig('batteryohare.png')
plt.show()

# %%
plot_list = []
for year in years:
    try:
        plot_list.append(Ohare[year]['ASSAULT'])
    except:
        plot_list.append(0)

fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,plot_list)
plt.title("Assault Rate - O'Hare ST 2001-2017")
plt.xlabel('Assault')
plt.ylabel('Year')
plt.show()
plt.savefig('Assaultohare.png')

# %%
State = {}
for year in years:
    small_df = df[df['Year'] == year]
    small_df = small_df[small_df['Block'] == '001XX N STATE ST']
    State[year] = small_df['Primary Type'].value_counts()

# %%
plot_list = []
for year in years:
    try:
        plot_list.append(State[year]['THEFT'])
    except:
        plot_list.append(0)
        
fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,plot_list)
plt.title("Theft Rate - State ST 2001-2017")
plt.xlabel('Theft')
plt.ylabel('Year')
plt.show()
plt.savefig('TheftState.png')

# %%
plot_list = []
for year in years:
    try:
        plot_list.append(State[year]['ASSAULT'])
    except:
        plot_list.append(0)

fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,plot_list)
plt.title("Assault Rate - State ST 2001-2017")
plt.xlabel('Assault')
plt.ylabel('Year')
plt.show()
plt.savefig('AssaultState.png')

# %%
plot_list = []
for year in years:
    try:
        plot_list.append(State[year]['BATTERY'])
    except:
        plot_list.append(0)
        
fig, ax = plt.subplots(figsize=(10,5))
g = plt.plot(years,plot_list)
plt.title("Battery Rate - State ST 2001-2017")
plt.xlabel('Battery')
plt.ylabel('Year')
plt.show()
plt.savefig('batterystate.png')
